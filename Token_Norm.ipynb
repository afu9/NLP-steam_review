# %%
import numpy as np
import pandas as pd
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import wordnet

stop_words = stopwords.words('english')
wordnet_lemmatizer = WordNetLemmatizer()
data = pd.read_csv("game_review(1200).csv", header=0)
review = data["review"].values.tolist()
pattern = r'\w[\w\'-]*\w'

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

    
init_reviews = []
for doc in review:
    doc = doc.lower()
    tokens = nltk.regexp_tokenize(doc, pattern)
    tagged_tokens= nltk.pos_tag(tokens)
    lemmatized_words=[wordnet_lemmatizer.lemmatize(word, get_wordnet_pos(tag)) \
          for (word, tag) in tagged_tokens \
          if word not in stop_words and word not in string.punctuation]
    temp_str = ""
    for item in lemmatized_words:
        temp_str = temp_str + " " + item
    init_reviews.append(temp_str[1:])
    
df = pd.DataFrame()
df["review"] = init_reviews
df["post_date"] = data["post_date"].values.tolist()
df["useful"] = data["useful"].values.tolist()

df.where(df.review!='').dropna()

#df.to_csv('tokened_normed_review.csv',index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-18fed7914b50> in <module>()
#      36         temp_str = temp_str + " " + item
#      37     if temp_str == '': temp_str = np.nan
# ---> 38     init_reviews.append(temp_str[1:])
#      39
#      40 df = pd.DataFrame()
#
# TypeError: 'float' object is not subscriptable

# %%
#[x for x in df["review"] if x=='']
print(len(df))
df.dropna(axis=1, how='any')
len(df)
# Out:
# 1197
# 1197

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df.where(df.review=='')
# Out:
#      review post_date useful
# 0       NaN       NaN    NaN
# 1       NaN       NaN    NaN
# 2       NaN       NaN    NaN
# 3       NaN       NaN    NaN
# 4       NaN       NaN    NaN
# 5       NaN       NaN    NaN
# 6       NaN       NaN    NaN
# 7       NaN       NaN    NaN
# 8       NaN       NaN    NaN
# 9       NaN       NaN    NaN
# 10      NaN       NaN    NaN
# 11      NaN       NaN    NaN
# 12      NaN       NaN    NaN
# 13      NaN       NaN    NaN
# 14      NaN       NaN    NaN
# 15      NaN       NaN    NaN
# 16      NaN       NaN    NaN
# 17      NaN       NaN    NaN
# 18      NaN       NaN    NaN
# 19      NaN       NaN    NaN
# 20      NaN       NaN    NaN
# 21      NaN       NaN    NaN
# 22      NaN       NaN    NaN
# 23      NaN       NaN    NaN
# 24      NaN       NaN    NaN
# 25      NaN       NaN    NaN
# 26      NaN       NaN    NaN
# 27      NaN       NaN    NaN
# 28      NaN       NaN    NaN
# 29      NaN       NaN    NaN
# ...     ...       ...    ...
# 1167    NaN       NaN    NaN
# 1168    NaN       NaN    NaN
# 1169    NaN       NaN    NaN
# 1170    NaN       NaN    NaN
# 1171    NaN       NaN    NaN
# 1172    NaN       NaN    NaN
# 1173    NaN       NaN    NaN
# 1174    NaN       NaN    NaN
# 1175    NaN       NaN    NaN
# 1176    NaN       NaN    NaN
# 1177    NaN       NaN    NaN
# 1178    NaN       NaN    NaN
# 1179    NaN       NaN    NaN
# 1180    NaN       NaN    NaN
# 1181    NaN       NaN    NaN
# 1182    NaN       NaN    NaN
# 1183    NaN       NaN    NaN
# 1184    NaN       NaN    NaN
# 1185    NaN       NaN    NaN
# 1186    NaN       NaN    NaN
# 1187    NaN       NaN    NaN
# 1188    NaN       NaN    NaN
# 1189    NaN       NaN    NaN
# 1190    NaN       NaN    NaN
# 1191    NaN       NaN    NaN
# 1192    NaN       NaN    NaN
# 1193    NaN       NaN    NaN
# 1194    NaN       NaN    NaN
# 1195    NaN       NaN    NaN
# 1196    NaN       NaN    NaN
#
# [1197 rows x 3 columns]

# %%
df.where(df.review!='').dropna()
# Out:
#                                                  review           post_date  \
# 0     let's see game release early access lot promis...  September 14, 2017
# 1     blah blah blah best rpg literally past 10 year...          January 22
# 2     game great middle finger money-grubbing aaa ga...    October 25, 2017
# 3     one best crpg fan roleplay game definitely mus...     August 15, 2017
# 4     early access review love game like game hold h...        June 5, 2017
# 5     divinity original sin like play enthusiastic d...             March 2
# 6     talk chicken claim mighty wizard call liar chi...   November 16, 2017
# 7     game masterpiece easily one best game ever pla...    November 4, 2017
# 8     tire game test reaction skill tire game say 60...  September 23, 2017
# 9     i'm 48 i've play pc game since zork best rpg i...  September 15, 2017
# 10    animal modern rpgs player click cat cat meow s...         February 16
# 11    hit 400 hour divinity original sin feel like f...             June 25
# 12    cannot recommend game enough rpg break boundar...              June 3
# 13             like turn-based game best game ever play    October 17, 2017
# 14    early access review know blasphemy say easily ...        May 28, 2017
# 15    avid crpg tabletop rpg player divinity o fun i...  September 17, 2017
# 16    never play first one hate turn-based combat bu...  September 14, 2017
# 17    early access review game developer half talent...     August 12, 2017
# 18    simply put divinity original sin expands best ...  September 15, 2016
# 19    i'm 72 year old best 20 hour life edit play ga...  September 19, 2017
# 20    without doubt one best rpgs ever play complete...    October 21, 2017
# 21    hand one best crpgs recent history i'm willing...  September 23, 2017
# 22    former black isle designer i'm rather critical...         February 13
# 23    play game week say dos2 replace skyrim time fa...            August 4
# 24    play play easily one great rpgs ever make woul...       June 24, 2017
# 25    adventure describe divinity original sin word ...    November 7, 2017
# 26    play witcher experience another's fantasy adve...   December 23, 2017
# 27    divinity original sin larian's second foray gr...            March 13
# 28    craft spell potion recipe ridiculous amount de...  September 19, 2017
# 29    i'm 35 year old first time i've happy cry enti...            April 25
# ...                                                 ...                 ...
# 1167  rts ttrpg importantly different feel like game...  September 14, 2017
# 1168  larian teach bioware make actual sequel game e...  September 19, 2017
# 1169  ball deep game since witcher seriously game i'...  September 18, 2017
# 1170  wonderful thing i've ever lay hand upon 10 10 ...  September 20, 2017
# 1171  absolutely love far complex game incredibly re...  September 18, 2017
# 1172  friend play first game dozen hour love enhance...  September 15, 2017
# 1173  far friend enjoy game story pretty deep combat...  September 23, 2017
# 1174  wait game long time play alpha want fully expe...  September 26, 2017
# 1175  great game love played beat part game like arx...     October 3, 2017
# 1176  meet woman daughter madman kill long ago tell ...  September 27, 2017
# 1177  game amaze one best genre far easy get bad thi...     October 3, 2017
# 1178  one enjoyable rpg game i've ever play one top ...  September 24, 2017
# 1179                              amaze favor play game            March 11
# 1180  want give quick thumb game absolutely deserve ...     October 1, 2017
# 1181  product receive free early access review divin...    October 21, 2016
